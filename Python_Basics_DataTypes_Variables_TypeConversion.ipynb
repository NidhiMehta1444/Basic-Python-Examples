# %% [markdown]
# ## Data Types in Python

# %% [markdown]
# 1. int
# 2. float
# 3. string
# 4. boolean
# 5. complex
# 6. list
# 7. tuple
# 8. set
# 9. dictionary

# %%
#int
print(4)
# Out:
# 4

# %%
#float
print(4.5)
# Out:
# 4.5

# %%
#string

print("mumbai")
# Out:
# mumbai

# %%
#boolean

print(True)
print(False)
# Out:
# True
# False

# %%
#complex

print(4+6j)
# Out:
# (4+6j)

# %%
#list

print([1,2,3,4,5])
# Out:
# [1, 2, 3, 4, 5]

# %%
#tuple

print((1,2,3,4,5))
# Out:
# (1, 2, 3, 4, 5)

# %%
#sets

print({1,2,3,4,5})
# Out:
# {1, 2, 3, 4, 5}

# %%
#dictionary

print({"Name": "Ram", "Age":20,"Gender":"Male"})
# Out:
# {'Name': 'Ram', 'Age': 20, 'Gender': 'Male'}

# %% [markdown]
# # Type Function

# %%
type(4)
# Out:
# int

# %%
type(4+6j)
# Out:
# complex

# %%
type([1,2,3,4,5])
# Out:
# list

# %%
type({"Name":"Ram"})
# Out:
# dict

# %% [markdown]
# # Input Function

# %%
input()
# Out:
#  hi
# 'hi'

# %%
input("Enter your name here")
# Out:
# Enter your name here ram
# 'ram'

# %% [markdown]
# # Variables

# %% [markdown]
# # Dynamic Typing

# %%
a=2
print(a)
# Out:
# 2

# %% [markdown]
# # Dynamic Binding

# %%
a=2
print(a)

a="India"
print(a)
# Out:
# 2
# India

# %% [markdown]
# # Type Conversion

# %% [markdown]
# ### Type Conversion means converting one data type to another

# %% [markdown]
# #### Explicit type conversion

# %%
first=input("Enter the 1st number")
second=input("Enter the 2nd number")
# Out:
# Enter the 1st number 32
# Enter the 2nd number 32

# %%
print(first)
print(second)
# Out:
# 32
# 32

# %%
print(first+second)
# Out:
# 3232

# %%
type(first)
# Out:
# str

# %%
type(second)
# Out:
# str

# %%
int(5.6)
# Out:
# 5

# %%
int('5')
# Out:
# 5

# %%
str(5)
# Out:
# '5'

# %%
float(5)
# Out:
# 5.0

# %%
list("goa")
# Out:
# ['g', 'o', 'a']

# %%
complex(5)
# Out:
# (5+0j)

# %%
int(first)+int(second)
# Out:
# 64

# %% [markdown]
# ### Implicit Type conversion

# %% [markdown]
# ### Program is happening automatically behind the scenes the programmer is not requestting it

# %%
int(5 + 4.5)
# Out:
# 9

# %% [markdown]
# # Keywords and Identifiers

# %% [markdown]
# 1. In python there are 32 keywords.
# 2. Keywords are reserved word by the compiler/Interpreter which the programmer cannot use.

# %% [markdown]
# ### Identifiers
#
# 1. Identifiers are names created by the programmer in a program
# 2. variable name
# 3. Function name
# 4. Class name
#
# Rules
# 1. You cant start with a digit
# 2. you can use only _ as a special chars
# 3. Keywords != Identifiers

# %% [markdown]
# # Literals

# %% [markdown]
# ## Literals are values assigned to a variable

# %% [markdown]
#  a=2
# 1. where a is variable name
# 2.      = is assignment operator
# 3.      2 is LITERAL

# %%
a=0X0000

# %%
print(a)
# Out:
# 0

# %%
x=None   # None is nothing

# %%
print(x)
# Out:
# None
